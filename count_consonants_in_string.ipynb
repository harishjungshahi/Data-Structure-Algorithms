# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/count_consonants_in_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def count_consonants(s):
  vowels = "aeiouAEIOU"
  count = 0

  for char in s:
    if char.isalpha() and char not in vowels:
      count += 1

  return count

print(count_consonants("Harish"))
# Out:
# 4
