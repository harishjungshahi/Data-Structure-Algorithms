# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/generate_number_triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generate_number_triangle(n):
    triangle = []

    for i in range(1, n + 1):
        triangle.append(str(i) * i)

    return triangle
for row in generate_number_triangle(5):
    print(row)
# Out:
# 1
# 22
# 333
# 4444
# 55555
