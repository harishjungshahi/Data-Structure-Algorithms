# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/check_subsequence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_subsequence(s,t):
  i=0
  j=0

  while i<len(s) and j<len(t):
    if s[i]==t[j]:
      j +=1
    i+=1

  if j==len(t):
    return True
  else:
    return False

print(is_subsequence("abcde","abe"))
print(is_subsequence("abcde","aec"))
# Out:
# True
# False
