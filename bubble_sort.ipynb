# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/bubble_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bubble_sort(arr):
    n = len(arr)

    for passes in range(0,n):
        for j in range(0,n-1):
            if(arr[j]>arr[j+1]):
                arr[j],arr[j+1]=arr[j+1],arr[j]

    return arr

unsorted_list = [12,25,11,34,90,22]
sorted_list = bubble_sort(unsorted_list)
print("Sorted Elements :", sorted_list)
# Out:
# Sorted Elements : [11, 12, 22, 25, 34, 90]
