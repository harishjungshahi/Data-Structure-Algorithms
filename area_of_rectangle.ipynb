# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/area_of_rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def area_of_rectangle(length, breadth):
    """
    Function to calculate the area of a rectangle.

    Parameters:
    length (float): The length of the rectangle.
    breadth (float): The breadth of the rectangle.

    Returns:
    float: The area of the rectangle.
    """
    # Your code here
    return length * breadth

print(area_of_rectangle(7.5, 2.4))
# Out:
# 18.0
