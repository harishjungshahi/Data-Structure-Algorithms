# %% [markdown]
# <a href="https://colab.research.google.com/github/harishjungshahi/Data-Structure-Algorithms/blob/main/generate_square.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generate_square(n):
    """
    Function to return a square pattern of '*' of side n as a list of strings.

    Parameters:
    n (int): The size of the square.

    Returns:
    list: A list of strings where each string represents a row of the square.
    """
    square = []
    for i in range(n):
        square.append('*' * n)
    return square

# Example
print(generate_square(3))
print(generate_square(5))
# Out:
# ['***', '***', '***']
# ['*****', '*****', '*****', '*****', '*****']
